# %% [markdown]
# ---
# output-file: a_contrast_plot_of_palmer_penguins.html
# title: A Contrast Plot of Palmer Penguins
# author: "Sangyu Xu"
# date: "09/18/2023"
# date-modified: "09/18/2021"
#
# ---

# %%
import pandas as pd
import dabest
from palmerpenguins import load_penguins
import dabest
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
penguins = load_penguins()
a = dabest.load(data = penguins, x = 'species', idx = tuple(penguins.species.unique()), y = 'body_mass_g');
f = a.mean_diff.plot();
